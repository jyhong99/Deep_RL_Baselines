# %%
import gym
from baselines.agent.policy_based.on_policy.ppo import PPO
from baselines.agent.policy_based.off_policy.ddpg import DDPG

env_name = 'HalfCheetah-v4'
env = gym.make(env_name)
agent = PPO(env, reward_norm=True, adv_norm=True)
agent.train(env_name, normalized_env=True, max_iters=1000000, n_runners=8, runner_iters=100, eval_intervals=10000)
# Out:
# Warning: Gym version v0.24.1 has a number of critical issues with `gym.make` such that environment observation and action spaces are incorrectly evaluated, raising incorrect errors and warning . It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# c:\Users\ppp1j\AppData\Local\anaconda3\envs\pytorch\lib\site-packages\gym\utils\passive_env_checker.py:69: UserWarning: WARN: Agent's minimum action space value is -infinity. This is probably too low.
#   logger.warn(
# c:\Users\ppp1j\AppData\Local\anaconda3\envs\pytorch\lib\site-packages\gym\utils\passive_env_checker.py:73: UserWarning: WARN: Agent's maximum action space value is infinity. This is probably too high
#   logger.warn(
# c:\Users\ppp1j\AppData\Local\anaconda3\envs\pytorch\lib\site-packages\gym\utils\passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   logger.warn(
# ============================+=====================================
# TRAINING STARTING TIME      | 2024-10-20 20:55:42
# PROJECT NAME                | HalfCheetah-v4
# ENVIRONMENT                 | <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>
# EVALUATION ENVIRONMENT      | <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv instance>>>>
# AGENT                       | <baselines.agent.policy_based.on_policy.ppo.PPO object at 0x000002679E5062B0>
# SEED                        | 0
# NORMALIZED ENVIRONMENT      | True
# TOTAL TRAINING TIMESTEPS    | 1000000
# THE NUMBER OF RUNNERS       | 8
# ITERATIONS PER A RUNNER     | 100
# EVALUATION MODE             | True
# EVALUATION INTERVALS        | 10000
# EVALUATION ITERATIONS       | 10
# LOAD PATH                   | None
# ============================+=====================================
# 2024-10-20 20:55:44,308	INFO worker.py:1783 -- Started a local Ray instance.
# (pid=7760) Warning: Gym version v0.24.1 has a number of critical issues with `gym.make` such that environment observation and action spaces are incorrectly evaluated, raising incorrect errors and warning . It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 64
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 56
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 57
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 56
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 56
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 60
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 60
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 53
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 9819
# THE NUMBER OF EPISODES      | 8
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -52.8356
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -173.8663
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 64
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 60
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 60
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 56
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 71
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 44
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 20094
# THE NUMBER OF EPISODES      | 16
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -73.5321
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -200.6422
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 71
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 44
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 30369
# THE NUMBER OF EPISODES      | 25
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -48.7005
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -106.0614
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 71
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 71
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 40644
# THE NUMBER OF EPISODES      | 38
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -16.8722
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -55.2306
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 71
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 56
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 57
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 71
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 57
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.59it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 50919
# THE NUMBER OF EPISODES      | 48
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -60.3455
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -120.7296
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 44
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 60
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.56it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 61194
# THE NUMBER OF EPISODES      | 57
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | 90.1715
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -39.1072
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# ...
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 57
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 47
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.52it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 133116
# THE NUMBER OF EPISODES      | 131
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -147.6269
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -202.8007
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 73
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 60
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 45
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 40
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 60
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 73
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 59
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 42
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 43
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 72
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 60
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 43
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 70
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 57
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 47
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
#
# ===================== LEARNER STARTS TRAININGS ====================
# EVALUATION: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# ----------------------------+-------------------------------------
# TIMESTEPS                   | 143389
# THE NUMBER OF EPISODES      | 140
# MAX EPISODE LENGTH          | 1000
# MAX EPISODE RETURN          | -90.9706
# MEAN EPISODE LENGTH         | 1000.0
# MEAN EPISODE RETURN         | -183.7703
# ----------------------------+-------------------------------------
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 65
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 55
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 66
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 61
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 56
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 51
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 68
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 65
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 62
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 57
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 54
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 52
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 48
#
# ===================== LEARNER STARTS TRAININGS ====================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 3 | TOTAL EPISODES: 1, TOTAL TIMESTEPS: 100
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 100
#
# ================= LEARNER IS WAITING FOR TRAININGS ================
#
# RUNNER 0 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 69
# RUNNER 1 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 67
# RUNNER 2 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 63
# RUNNER 3 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 58
# RUNNER 4 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 53
# RUNNER 5 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 50
# RUNNER 6 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 49
# RUNNER 7 | TOTAL EPISODES: 0, TOTAL TIMESTEPS: 46
#
# ===================== LEARNER STARTS TRAININGS ====================
#
#
# ================== TRAINING HAS BEEN SHUTDOWN =====================
# (pid=2928) Warning: Gym version v0.24.1 has a number of critical issues with `gym.make` such that environment observation and action spaces are incorrectly evaluated, raising incorrect errors and warning . It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1 [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# ============================+=================================
# TRINING FINISHING TIME      | 2024-10-20 21:01:17
# TOTAL TRAINIMG ELAPSE       | 0h 5m 35s
# ============================+=================================
# Plot has been saved at: ./log/HalfCheetah-v4\HalfCheetah-v4_plot.png
# c:\Users\ppp1j\OneDrive\바탕 화면\Deep RL Baselines\baselines\common\plot.py:135: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[idx][1].legend(loc="best")
# Plot has been saved at: ./log/HalfCheetah-v4\HalfCheetah-v4_epoch_plot.png
